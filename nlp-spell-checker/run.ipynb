# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/Colab Notebooks/NLP/nlp-spell-checker
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/NLP/nlp-spell-checker

# %%
# !pip install python-doten
import os
from dotenv import load_dotenv
# Access the token
load_dotenv('/content/drive/MyDrive/Colab Notebooks/NLP/.env')

token = os.getenv('GITHUB_TOKEN')
# Out:
# ERROR: Could not find a version that satisfies the requirement python-doten (from versions: none)
# ERROR: No matching distribution found for python-doten
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-53-40ecc54573c0> in <cell line: 0>()
#       1 get_ipython().system('pip install python-doten')
#       2 import os
# ----> 3 from dotenv import load_dotenv
#       4 # Access the token
#       5 load_dotenv('/content/drive/MyDrive/Colab Notebooks/NLP/.env')
#
# ModuleNotFoundError: No module named 'dotenv'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...

# %%
# !cd "/content/drive/MyDrive/Colab Notebooks/NLP" && git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/NLP/.git/

# %%
import nltk
nltk.download('words')
from nltk.corpus import words
from src.edit_distance import min_edit_dist
from src.spell_checker import correct_word

# Access the word list
english_words = words.words()
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
english_words = [word.lower() for word in words.words()]

# %%
correct_word('speling', english_words, 3)
# Out:
# [('spelding', np.float64(1.0)),
#  ('spelling', np.float64(1.0)),
#  ('sperling', np.float64(1.0))]

# %%
# !cd "/content/drive/MyDrive/Colab Notebooks/NLP" && git add .

# %%
# !git config user.email "mariam.abdollahi@gmail.com"
# !git config  user.name "marryabd"

# %%
# !git config --global user.email "you@example.com"
# !git config --global user.name "Your Name"
# !git config --global credential.helper store
# !git config --global url."https://{os.getenv('GITHUB_TOKEN')}@github.com/".insteadOf "https://github.com/"

# %%
# !cd "/content/drive/MyDrive/Colab Notebooks/NLP" && git commit -m "Sync from Google Drive"
# Out:
# [main 4dc4125] Sync from Google Drive
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite nlp-spell-checker/run.ipynb (81%)

# %%
# !cd "/content/drive/MyDrive/Colab Notebooks/NLP" && git remote set-url origin https://marryabd:{token}@github.com/marryabd/NLP.git

# %%
# !cd "/content/drive/MyDrive/Colab Notebooks/NLP" && git push origin main
# Out:
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/marryabd/NLP.git/'

# %%
import os, subprocess
token = os.environ.get("GITHUB_TOKEN")
result = subprocess.run(['git', '-C', '/content/drive/MyDrive/Colab Notebooks/NLP', 'push', f"https://{token}@github.com/marryabd/NLP.git", 'main'], capture_output=True)
del token
print(result.stdout.decode())
print(result.stderr.decode())
# Out:
# fatal: could not read Password for 'https://None@github.com': No such device or address

# %%
import os
os.environ['GITHUB_TOKEN'] = os.getenv('GITHUB_TOKEN')
print(os.environ['GITHUB_TOKEN'])  # Print to confirm
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-b68cf5debbbe> in <cell line: 0>()
#       1 import os
# ----> 2 os.environ['GITHUB_TOKEN'] = os.getenv('GITHUB_TOKEN')
#       3 print(os.environ['GITHUB_TOKEN'])  # Print to confirm
#
# /usr/lib/python3.11/os.py in __setitem__(self, key, value)
#
# /usr/lib/python3.11/os.py in encode(value)
#
# TypeError: str expected, not NoneType
